# %%
import shutil
import os
import time
import oss2
import schedule

def backupLocal(path='backup'):
    '''if not os.path.exists(backup_path):
        os.makedirs(backup_path)
    date_str=time.strftime('%Y%m%d%H%M%S')
    backup_file=os.path.join(backup_path,f'backup_{date_str}.zip')
    shutil.make_archive(base_name=backup_file.replace('.zip',''),
                       format='zip',
                       root_dir=file_path)
    return backup_file'''
    files=[file for file in os.listdir('.') if os.path.isfile(file)]
    if not os.path.exists(path):
        os.makedirs(path)
    #os.chdir('../')
    os.chdir(path)
    date=time.strftime('%Y%m%d%H%M%S')
    os.makedirs(f'{date}')
    for file in files:
        shutil.copy(f'../{file}',f'../{path}/{date}/{file}')
    os.chdir('../')
    
def uploadOSS(file_path,bucket_name,key_id,key_secret,endpoint):
    auth=oss2.Auth(key_id,key_secret)
    bucket=oss2.Bucket(auth,endpoint,bucket_name)
    object_name=os.path.basename(file_path)
    with open(file_path,'rb') as fileobj:
        bucket.put_object(object_name,fileobj)
    print(f'文件{object_name}成功上传到OSS存储桶{bucket_name}')

def cleanOldBackups(folder,days=7):
    now=time.time()
    for file in os.listdir(folder):
        file_path=os.path.join(folder,file)
        if os.path.isfile(file_path):
            file_mtime=os.path.getmtime(file_path)
            if (now-file_mtime)>retention_days*86400:
                os.remove(file_path)
                
def autoBackup(file_path,backup_path,bucket_name,key_id,key_secret,endpoint):
    local_file=backupLocal(file_path,backup_path)
    if local_file:
        uploadOSS(local_file,bucket_name,key_id,key_secret,endpoint)
    cleanOldBackups('backup')

'''if __name__=='__main__':
    schedule.every().day.at('02:00').do(daily_backup_job)
    while True:
        schedule.run_pending()
        time.sleep(60)'''
    
if __name__=='__main__':
    backupLocal()
