# %%
'''import base64
import rsa
import hashlib
from cryptography.fernet import Fernet'''
import os
import pyDes
import random
import string
import time
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad

def randomString(length):
    letters=string.ascii_letters+string.digits
    return ''.join(random.choice(letters) for _ in range(length))

def encrypt3DES(file_path):
    key=randomString(16)
    iv=time.strftime('%d%H%M%S')
    des=pyDes.triple_des(key,pyDes.CBC,iv,pad=None,padmode=pyDes.PAD_PKCS5)
    with open(file_path,'rb') as encry_in:
        with open(f'3DES_{key}_{file_path}','wb') as encry_out:
            encry_out.write(des.encrypt(encry_in.read()))

def encryptAES(file_path):
    key=randomString(16)
    iv=f'{key[4:12]}{dt.strftime('%d%H%M%S')}'
    aes=AES.new(key,AES.MODE_CBC,iv)
    with open(file_path,'rb') as encry_in:
        with open(f'AES_{key}_{file_path}','wb') as encry_out:
            encry_out.write(aes.encrypt(pad(encry_in.read(),AES.block_size)))
               
if __name__=='__main__':
    encrypt3DES('新建文件夹.zip')

'''def CaesarCode(file_path,step):
    with open(file_path,'rb') as file:
        data=file.read()
    source=base64.b64encode(data).decode()
    result=''
    #对字符串加密
    for i in source:
        #对大小写字母右移step位进行加密
        if ord(i) in range(97,123) or ord(i) in range(65,91):
            result+=chr(ord(i)+step)
        else:
            result+=i
    os.remove(file_path)
    with  open(file_path+'.enc','w') as file:
        file.write(result)

def password(file_path,password):
    fernet=Fernet(passward)
    with open(file_path,'rb') as file:
        original=file.read()
    encrypted=fernet.encrypt(original)
    with open(filename,'wb') as enc_file:
        enc_file.write(encrypted)

def rsaEnc(file_path,public_key_file):
    with open(file_path,'rb') as file:
        file_content=file.read()
    with open(public_key_file,'rb') as key_file:
        public_key=rsa.PublicKey.load_pkcs1(key_file.read())
    encrypted=rsa.encrypt(file_content,public_key)
    with open(file_path,'wb') as file:
        file.write(encrypted)
    
def sha256Pre(file_content):
    content=[]
    for x in file_content:
        content.append(bin(x))
    content.append('0b10000000')
    while len(content)%64!=56:
        content.append('0b0')
    endding=bin(len(file_content))
    size=(len(endding)-3)//8
    for i in range(7-size):
        content.append('0b0')
    if size==0:
        content.append(endding)
    else:
        tag=size*8-len(endding)
        content.append(endding[:-tag])
        for i in range(size-1):
            content.append('0b'+endding[i*8-tag:i*8+8-tag])
        content.append('0b'+endding[-8:])
    return content

def rightRotate(x,num):
    return (x>>>num)|(x<<-num)
def sha256Enc(file_path):
    H=[0x6a09e667,0xbb67ae85,0x3c6ef372,0xa54ff53a,0x510e527f,0x9b05688c,0x1f83d9ab,0x5be0cd19]
    k=[0x428a2f98,0x71374491,0xb5c0fbcf,0xe9b5dba5,0x3956c25b,0x59f111f1,0x923f82a4,0xab1c5ed5,
       0xd807aa98,0x12835b01,0x243185be,0x550c7dc3,0x72be5d74,0x80deb1fe,0x9bdc06a7,0xc19bf174,
       0xe49b69c1,0xefbe4786,0x0fc19dc6,0x240ca1cc,0x2de92c6f,0x4a7484aa,0x5cb0a9dc,0x76f988da,
       0x983e5152,0xa831c66d,0xb00327c8,0xbf597fc7,0xc6e00bf3,0xd5a79147,0x06ca6351,0x14292967,
       0x27b70a85,0x2e1b2138,0x4d2c6dfc,0x53380d13,0x650a7354,0x766a0abb,0x81c2c92e,0x92722c85,
       0xa2bfe8a1,0xa81a664b,0xc24b8b70,0xc76c51a3,0xd192e819,0xd6990624,0xf40e3585,0x106aa070,
       0x19a4c116,0x1e376c08,0x2748774c,0x34b0bcb5,0x391c0cb3,0x4ed8aa4a,0x5b9cca4f,0x682e6ff3,
       0x748f82ee,0x78a5636f,0x84c87814,0x8cc70208,0x90befffa,0xa4506ceb,0xbef9a3f7,0xc67178f2]
    with open(file_path,'rb') as file:
        file_content=file.read()
    content=sha256Pre(file_content)
    n=len(content)//64
    display(n)
    [a,b,c,d,e,f,g,h]=H
    for i in range(n):
        for j in range(64):
            t1=((e>>6)|(e<<-6))^(
            t2=
            h=g
            g=f
            f=e
            e=d+t1
            d=c
            c=b
            b=a
            a=t1+t2
        H+=[a,b,c,d,e,f,g,h]
        digest=h0||h1||h2||h3||h4||h5||h6||h7'''
        
'''if __name__=='__main__':
    #sha256Enc('1.txt')
    print(help(hashlib.sha256))'''
# Out:
# hZBOSAVubpTfA6hU 10131123
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 33
#      30             encry_out.write(aes.encrypt(pad(encry_in.read(),AES.block_size)))
#      32 if __name__=='__main__':
# ---> 33     encrypt3DES('新建文件夹.zip')
#      35 '''def CaesarCode(file_path,step):
#      36     with open(file_path,'rb') as file:
#      37         data=file.read()
#    (...)
#     119         H+=[a,b,c,d,e,f,g,h]
#     120         digest=h0||h1||h2||h3||h4||h5||h6||h7'''
#     122 '''if __name__=='__main__':
#     123     #sha256Enc('1.txt')
#     124     print(help(hashlib.sha256))'''
#
# Cell In[7], line 22, in encrypt3DES(file_path, key, iv)
#      20 print(key1,iv1)
#      21 des=pyDes.triple_des(key,pyDes.CBC,iv,pad=None,padmode=pyDes.PAD_PKCS5)
# ---> 22 with open(file_path,'rb') as encry_in:
# ...
